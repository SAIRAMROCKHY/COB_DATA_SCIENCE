# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/dataset - netflix1.csv")
df.head(10)
# Out:
#   show_id     type                             title             director  \
# 0      s1    Movie              Dick Johnson Is Dead      Kirsten Johnson
# 1      s3  TV Show                         Ganglands      Julien Leclercq
# 2      s6  TV Show                     Midnight Mass        Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl        Bruno Garotti
# 4      s8    Movie                           Sankofa         Haile Gerima
# 5      s9  TV Show     The Great British Baking Show      Andy Devonshire
# 6     s10    Movie                      The Starling       Theodore Melfi
# 7    s939    Movie   Motu Patlu in the Game of Zones          Suhas Kadav
# 8     s13    Movie                      Je Suis Karl  Christian Schwochow
# 9    s940    Movie          Motu Patlu in Wonderland          Suhas Kadav
#
#           country date_added  release_year rating   duration  \
# 0   United States  9/25/2021          2020  PG-13     90 min
# ...

# %%
df['director']= df['director'].replace('Not Given', np.NaN)
df['country']= df['country'].replace('Not Given', np.NaN)

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2588
# country          287
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# dtype: int64

# %%
df1= df.dropna(axis=0, how='any')
df1.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df1.head(10)
# Out:
#   show_id     type                             title             director  \
# 0      s1    Movie              Dick Johnson Is Dead      Kirsten Johnson
# 1      s3  TV Show                         Ganglands      Julien Leclercq
# 2      s6  TV Show                     Midnight Mass        Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl        Bruno Garotti
# 4      s8    Movie                           Sankofa         Haile Gerima
# 5      s9  TV Show     The Great British Baking Show      Andy Devonshire
# 6     s10    Movie                      The Starling       Theodore Melfi
# 7    s939    Movie   Motu Patlu in the Game of Zones          Suhas Kadav
# 8     s13    Movie                      Je Suis Karl  Christian Schwochow
# 9    s940    Movie          Motu Patlu in Wonderland          Suhas Kadav
#
#           country date_added  release_year rating   duration  \
# 0   United States  9/25/2021          2020  PG-13     90 min
# ...

# %%
plt.figure(figsize=(30,12))
plt.bar(np.unique(df1["type"], return_counts=True)[0], np.unique(df1["type"], return_counts=True)[1])
plt.xticks(rotation=90, fontsize=18)
plt.yticks(fontsize=18)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(30,12))
plt.bar(np.unique(df1["release_year"], return_counts=True)[0], np.unique(df1["release_year"], return_counts=True)[1])
plt.xticks(rotation=90, fontsize=18)
plt.yticks(fontsize=18)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(30,12))
plt.bar(np.unique(df1["rating"], return_counts=True)[0], np.unique(df1["rating"], return_counts=True)[1])
plt.xticks(rotation=90, fontsize=18)
plt.yticks(fontsize=18)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(30,12))
plt.bar(np.unique(df1["country"], return_counts=True)[0], np.unique(df1["country"], return_counts=True)[1])
plt.xticks(rotation=90, fontsize=18)
plt.yticks(fontsize=18)
plt.grid()
plt.show()

# %%
fig = px.box(df,x='country',y='release_year',color='country',title='Year wise releases in each country',template='plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.boxplot(df1)
# Out:
# <Axes: >

# %%
upperlimit= 2018+1.5*6
lowerlimit= 2018-1.5*6
data_noOutlier= df1[(df1['release_year']>lowerlimit) & (df1['release_year']<upperlimit)]

# %%
sns.boxplot(x= data_noOutlier['release_year'])
# Out:
# <Axes: xlabel='release_year'>

# %%
sns.histplot(x= data_noOutlier['release_year'])
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>
